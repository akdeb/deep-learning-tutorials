# %%
s = "anyeongahsehoh 🤖 (hello in korean)"

# %%
[ord(x) for x in s]
# Out:
# [97,
#  110,
#  121,
#  101,
#  111,
#  110,
#  103,
#  97,
#  104,
#  115,
#  101,
#  104,
#  111,
#  104,
#  32,
#  129302,
#  32,
#  40,
#  104,
#  101,
#  108,
#  108,
#  111,
#  32,
#  105,
#  110,
#  32,
#  107,
#  111,
#  114,
#  101,
#  97,
#  110,
#  41]

# %%
list(s.encode("utf-16"))
# Out:
# [255,
#  254,
#  0,
#  0,
#  97,
#  0,
#  0,
#  0,
#  110,
#  0,
#  0,
#  0,
#  121,
#  0,
#  0,
#  0,
#  101,
#  0,
#  0,
#  0,
#  111,
#  0,
#  0,
#  0,
#  110,
#  0,
#  0,
#  0,
#  103,
#  0,
#  0,
#  0,
#  97,
#  0,
#  0,
#  0,
#  104,
#  0,
#  0,
#  0,
#  115,
#  0,
#  0,
#  0,
#  101,
#  0,
#  0,
#  0,
#  104,
#  0,
#  0,
#  0,
#  111,
#  0,
#  0,
#  0,
#  104,
#  0,
#  0,
#  0,
#  32,
#  0,
#  0,
#  0,
#  22,
#  249,
#  1,
#  0,
#  32,
#  0,
#  0,
#  0,
#  40,
#  0,
#  0,
#  0,
#  104,
#  0,
#  0,
#  0,
#  101,
#  0,
#  0,
#  0,
#  108,
#  0,
#  0,
#  0,
#  108,
#  0,
#  0,
#  0,
#  111,
#  0,
#  0,
#  0,
#  32,
#  0,
#  0,
#  0,
#  105,
#  0,
#  0,
#  0,
#  110,
#  0,
#  0,
#  0,
#  32,
#  0,
#  0,
#  0,
#  107,
#  0,
#  0,
#  0,
#  111,
#  0,
#  0,
#  0,
#  114,
#  0,
#  0,
#  0,
#  101,
#  0,
#  0,
#  0,
#  97,
#  0,
#  0,
#  0,
#  110,
#  0,
#  0,
#  0,
#  41,
#  0,
#  0,
#  0]
