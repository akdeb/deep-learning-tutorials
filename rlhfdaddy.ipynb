# %% [markdown]
# # Project 1: Simple 3X3 obstacle avoiding game
# ### Set up env and actions
# Env is made up of x and y co-ordinates

# %%
import numpy as np
import random
from typing import Tuple, List

GRID_SIZE = 3
START = (0,0)
GOAL = (GRID_SIZE-1, GRID_SIZE-1)

OBSTACLE = (1,1)

ACTIONS = [
    (-1,0),
    (0,1),
    (0,-1),
    (1,0)
]

# %%
def is_valid_state(state: Tuple[int, int]) -> bool:
    return (0 <= state[0] < GRID_SIZE and 0 <= state[1] < GRID_SIZE and state != OBSTACLE)

# %%
def get_next_state(state: Tuple[int, int], action: Tuple[int, int]) -> Tuple[int, int]:
    next_state = (state[0] + action[0], state[1] + action[1])
    return next_state if is_valid_state(next_state) else state

# %%
EPSILON = 0.3
ALPHA = 0.3
GAMMA = 0.99
EPISODES = 10000

# %%
def get_reward(state: Tuple[int, int], next_state: Tuple[int, int]) -> int:
    if next_state == GOAL:
        return 100
    elif next_state == OBSTACLE and next_state == state:
        return -10
    else:
        return -1

# %%
def choose_action(state: Tuple[int, int], q_table: np.ndarray) -> Tuple[int, int]:
    if random.uniform(0,1) < EPSILON:
        return random.choice(ACTIONS)
    else:
        return ACTIONS[np.argmax(q_table[state])]

# %%
def update_q_table(q_table: np.ndarray, state: Tuple[int, int], action: Tuple[int, int], reward: int, next_state: Tuple[int, int]) -> None:
    action_idx = ACTIONS.index(action)
    old_q_value = q_table[state][action_idx]
    q_table[state][action_idx] = old_q_value + ALPHA * (reward + GAMMA * np.max(q_table[next_state]) - old_q_value)

# %%
def train_agent() -> np.ndarray:
    q_table = np.zeros((GRID_SIZE, GRID_SIZE, len(ACTIONS)))
    for _ in range(EPISODES):
        state = START
        while state != GOAL:
            action = choose_action(state, q_table)
            next_state = get_next_state(state, action)
            reward = get_reward(state, next_state)
            update_q_table(q_table, state, action, reward, next_state)
            state = next_state

    return q_table

q_table = train_agent()

# %%
q_table
# Out:
# array([[[ 92.119202,  94.0598  ,  92.119202,  94.0598  ],
#         [ 94.0598  ,  96.02    ,  92.119202,  94.0598  ],
#         [ 96.02    ,  96.02    ,  94.0598  ,  98.      ]],
#
#        [[ 92.119202,  94.0598  ,  94.0598  ,  96.02    ],
#         [  0.      ,   0.      ,   0.      ,   0.      ],
#         [ 96.02    ,  98.      ,  98.      , 100.      ]],
#
#        [[ 94.0598  ,  98.      ,  96.02    ,  96.02    ],
#         [ 98.      , 100.      ,  96.02    ,  98.      ],
#         [  0.      ,   0.      ,   0.      ,   0.      ]]])

# %%
q_table[0][0][1]
# Out:
# 94.05979999999994

# %% [markdown]
# # Project 2: Balancing a Pole using Gymnasium

# %%
pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.19.0-cp311-cp311-macosx_12_0_arm64.whl.metadata (4.0 kB)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Downloading absl_py-2.2.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Users/akashdeepdeb/.pyenv/versions/3.11.11/lib/python3.11/site-packages (from tensorflow) (24.12.23)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Downloading gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Downloading libclang-18.1.1-1-py2.py3-none-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in /Users/akashdeepdeb/.pyenv/versions/3.11.11/lib/python3.11/site-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /Users/akashdeepdeb/.pyenv/versions/3.11.11/lib/python3.11/site-packages (from tensorflow) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/akashdeepdeb/.pyenv/versions/3.11.11/lib/python3.11/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /Users/akashdeepdeb/.pyenv/versions/3.11.11/lib/python3.11/site-packages (from tensorflow) (75.8.0)
# Requirement already satisfied: six>=1.12.0 in /Users/akashdeepdeb/.pyenv/versions/3.11.11/lib/python3.11/site-packages (from tensorflow) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Downloading termcolor-2.5.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/akashdeepdeb/.pyenv/versions/3.11.11/lib/python3.11/site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/akashdeepdeb/.pyenv/versions/3.11.11/lib/python3.11/site-packages (from tensorflow) (1.17.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/akashdeepdeb/.pyenv/versions/3.11.11/lib/python3.11/site-packages (from tensorflow) (1.67.1)
# Collecting tensorboard~=2.19.0 (from tensorflow)
#   Downloading tensorboard-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting keras>=3.5.0 (from tensorflow)
#   Downloading keras-3.9.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /Users/akashdeepdeb/.pyenv/versions/3.11.11/lib/python3.11/site-packages (from tensorflow) (1.26.4)
# Collecting h5py>=3.11.0 (from tensorflow)
#   Downloading h5py-3.13.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.5 kB)
# Collecting ml-dtypes<1.0.0,>=0.5.1 (from tensorflow)
#   Downloading ml_dtypes-0.5.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (21 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow)
#   Downloading tensorflow_io_gcs_filesystem-0.37.1-cp311-cp311-macosx_12_0_arm64.whl.metadata (14 kB)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow)
#   Using cached wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: rich in /Users/akashdeepdeb/.pyenv/versions/3.11.11/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Collecting namex (from keras>=3.5.0->tensorflow)
#   Downloading namex-0.0.8-py3-none-any.whl.metadata (246 bytes)
# Collecting optree (from keras>=3.5.0->tensorflow)
#   Downloading optree-0.14.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (49 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/akashdeepdeb/.pyenv/versions/3.11.11/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/akashdeepdeb/.pyenv/versions/3.11.11/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/akashdeepdeb/.pyenv/versions/3.11.11/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/akashdeepdeb/.pyenv/versions/3.11.11/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in /Users/akashdeepdeb/.pyenv/versions/3.11.11/lib/python3.11/site-packages (from tensorboard~=2.19.0->tensorflow) (3.7)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard~=2.19.0->tensorflow)
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/akashdeepdeb/.pyenv/versions/3.11.11/lib/python3.11/site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/akashdeepdeb/.pyenv/versions/3.11.11/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/akashdeepdeb/.pyenv/versions/3.11.11/lib/python3.11/site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/akashdeepdeb/.pyenv/versions/3.11.11/lib/python3.11/site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/akashdeepdeb/.pyenv/versions/3.11.11/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Downloading tensorflow-2.19.0-cp311-cp311-macosx_12_0_arm64.whl (252.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.6/252.6 MB 10.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading absl_py-2.2.0-py3-none-any.whl (276 kB)
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading h5py-3.13.0-cp311-cp311-macosx_11_0_arm64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 6.3 MB/s eta 0:00:006.5 MB/s eta 0:00:01
# Downloading keras-3.9.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 5.9 MB/s eta 0:00:000:00:01
# Downloading libclang-18.1.1-1-py2.py3-none-macosx_11_0_arm64.whl (25.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.8/25.8 MB 7.3 MB/s eta 0:00:007.3 MB/s eta 0:00:01
# Downloading ml_dtypes-0.5.1-cp311-cp311-macosx_10_9_universal2.whl (671 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 671.4/671.4 kB 10.8 MB/s eta 0:00:00
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 13.8 MB/s eta 0:00:0031m15.1 MB/s eta 0:00:01
# Downloading tensorflow_io_gcs_filesystem-0.37.1-cp311-cp311-macosx_12_0_arm64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 11.7 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading termcolor-2.5.0-py3-none-any.whl (7.8 kB)
# Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Using cached wheel-0.45.1-py3-none-any.whl (72 kB)
# Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Downloading optree-0.14.1-cp311-cp311-macosx_11_0_arm64.whl (335 kB)
# Installing collected packages: namex, libclang, wheel, termcolor, tensorflow-io-gcs-filesystem, tensorboard-data-server, optree, opt-einsum, ml-dtypes, h5py, google-pasta, gast, absl-py, tensorboard, astunparse, keras, tensorflow
# Successfully installed absl-py-2.2.0 astunparse-1.6.3 gast-0.6.0 google-pasta-0.2.0 h5py-3.13.0 keras-3.9.0 libclang-18.1.1 ml-dtypes-0.5.1 namex-0.0.8 opt-einsum-3.4.0 optree-0.14.1 tensorboard-2.19.0 tensorboard-data-server-0.7.2 tensorflow-2.19.0 tensorflow-io-gcs-filesystem-0.37.1 termcolor-2.5.0 wheel-0.45.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install gymnasium
# pip install "gymnasium[classic-control]"
# Out:
#   Cell In[20], line 1
#     pip install gymnasium
#         ^
# SyntaxError: invalid syntax

# %%
pip install "gymnasium[classic-control]"
# Out:
# Requirement already satisfied: gymnasium[classic-control] in /Users/akashdeepdeb/.pyenv/versions/3.11.11/lib/python3.11/site-packages (1.1.1)
# Requirement already satisfied: numpy>=1.21.0 in /Users/akashdeepdeb/.pyenv/versions/3.11.11/lib/python3.11/site-packages (from gymnasium[classic-control]) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/akashdeepdeb/.pyenv/versions/3.11.11/lib/python3.11/site-packages (from gymnasium[classic-control]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/akashdeepdeb/.pyenv/versions/3.11.11/lib/python3.11/site-packages (from gymnasium[classic-control]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/akashdeepdeb/.pyenv/versions/3.11.11/lib/python3.11/site-packages (from gymnasium[classic-control]) (0.0.4)
# Collecting pygame>=2.1.3 (from gymnasium[classic-control])
#   Downloading pygame-2.6.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (12 kB)
# Downloading pygame-2.6.1-cp311-cp311-macosx_11_0_arm64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 16.0 MB/s eta 0:00:00 MB/s eta 0:00:01
# Installing collected packages: pygame
# Successfully installed pygame-2.6.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import random
from collections import deque
import gymnasium as gym
import tensorflow as tf
from tensorflow.keras import Model, layers
import os

# %%
env = gym.make('CartPole-v1')
state_size = env.observation_space.shape[0]
action_size = env.action_space.n

print("Action size: ", action_size)
print("State size: ", state_size)
# Out:
# Action size:  2
# State size:  4

# %%
class DQN(Model):
    def __init__(self, action_size, **kwargs):
        super(DQN, self).__init__(**kwargs)
        self.action_size = action_size
        self.d1 = layers.Dense(24, activation='relu', name='d1')
        self.d2 = layers.Dense(24, activation='relu', name='d2')
        self.d3 = layers.Dense(action_size, activation='linear', name='d3')

    def call(self, x):
        return self.d3(self.d2(self.d1(x)))

    def get_config(self):
        config = super(DQN, self).get_config()
        config.update({"action_size": self.action_size})
        return config

    @classmethod
    def from_config(cls, config):
        return cls(**config)

memory = deque(maxlen=2000)

# %%
class Agent:
    def __init__(self, state_size, action_size, gamma=0.99, epsilon=1.0, epsilon_min=0.01, epsilon_decay=0.995, learning_rate=0.001):
        self.state_size = state_size
        self.action_size = action_size
        self.gamma = gamma
        self.epsilon = epsilon
        self.epsilon_min = epsilon_min
        self.epsilon_decay = epsilon_decay
        self.learning_rate = learning_rate

        self.model = self._build_model()
        self.target_model = self._build_model()
        self.update_target_model()

        self.optimizer = tf.keras.optimizers.Adam(learning_rate=self.learning_rate)

    def _build_model(self):
        return DQN(self.action_size)

    def update_target_model(self):
        self.target_model.set_weights(self.model.get_weights())

    def remember(self, state, action, reward, next_state, done):
        memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        q_values = self.model(np.array([state]))
        return np.argmax(q_values[0].numpy())

    def save_model(self, filepath):
        self.model.save(filepath)

    def load_model(self, filepath):
        self.model = tf.keras.models.load_model(filepath, custom_objects={"DQN": DQN})
        self.target_model = tf.keras.models.load_model(filepath, custom_objects={"DQN": DQN})

    def replay(self, batch_size):
        minibatch = random.sample(memory, batch_size)
        for state, action, reward, next_state, done in minibatch:
            with tf.GradientTape() as tape:
                q_values = self.model(np.array([state]), training=True)
                q_value = q_values[0][action]

                if done:
                    target = reward
                else:
                    next_action = np.argmax(self.model(np.array([next_state]))[0].numpy())
                    t = self.target_model(np.array([next_state]))[0][next_action]
                    target = reward + self.gamma * t

                loss = tf.reduce_mean(tf.square(target - q_value))

            grads = tape.gradient(loss, self.model.trainable_variables)
            self.optimizer.apply_gradients(zip(grads, self.model. trainable_variables))

# %%
batch_size = 32           # Number of samples used for each training step
n_episodes = 500          # Total number of episodes to train on
gamma = 0.95              # Discount factor for future rewards (0 to 1)
epsilon = 1.0             # Initial exploration rate (1 = 100% random actions)
epsilon_min = 0.01        # Minimum exploration rate
epsilon_decay = 0.995     # Decay factor for epsilon after each episode
learning_rate = 0.001     # Step size for neural network weight updates
update_target_every = 5   # Number of episodes between target network updates

# %%
output_dir = './cartpole_model/'

# Initialize the Agent
agent = Agent(state_size, action_size, gamma=gamma, epsilon=epsilon, epsilon_min=epsilon_min, epsilon_decay=epsilon_decay, learning_rate=learning_rate)
done = False

# Main Script
for e in range(n_episodes):
    state = env.reset()[0]
    state = np.reshape(state, [1, state_size])
    total_reward = 0

    for time_t in range(500):
        action = agent.act(state[0])
        next_state, reward, done, truncated, _ = env.step(action)
        done = done or truncated
        next_state = np.reshape(next_state, [1, state_size])
        agent.remember(state[0], action, reward, next_state[0], done)
        state = next_state
        total_reward += reward

        if done:
            print(f"Episode: {e}/{n_episodes}, Score: {time_t}, Epsilon: {agent.epsilon:.2f}")
            break

    if len(memory) > batch_size:
        loss = agent.replay(batch_size)

    # Update epsilon
    if agent.epsilon > agent.epsilon_min:
        agent.epsilon *= agent.epsilon_decay

    # Update target network
    if e % update_target_every == 0:
        agent.update_target_model()

    
    if e % 100 == 0:
        agent.save_model(os.path.join(output_dir, f'model_{e}.keras'))

agent.save_model(os.path.join(output_dir, f'model_500.keras'))
# Out:
# Episode: 0/500, Score: 22, Epsilon: 1.00
# Episode: 1/500, Score: 70, Epsilon: 0.99
# /Users/akashdeepdeb/.pyenv/versions/3.11.11/lib/python3.11/site-packages/keras/src/saving/saving_api.py:107: UserWarning: You are saving a model that has not yet been built. It might not contain any weights yet. Consider building the model first by calling it on some data.
#   return saving_lib.save_model(model, filepath)
# Episode: 2/500, Score: 28, Epsilon: 0.99
# Episode: 3/500, Score: 18, Epsilon: 0.99
# Episode: 4/500, Score: 14, Epsilon: 0.98
# Episode: 5/500, Score: 8, Epsilon: 0.98
# Episode: 6/500, Score: 15, Epsilon: 0.97
# Episode: 7/500, Score: 16, Epsilon: 0.97
# Episode: 8/500, Score: 15, Epsilon: 0.96
# Episode: 9/500, Score: 15, Epsilon: 0.96
# Episode: 10/500, Score: 11, Epsilon: 0.95
# Episode: 11/500, Score: 22, Epsilon: 0.95
# Episode: 12/500, Score: 21, Epsilon: 0.94
# Episode: 13/500, Score: 8, Epsilon: 0.94
# Episode: 14/500, Score: 20, Epsilon: 0.93
# Episode: 15/500, Score: 21, Epsilon: 0.93
# Episode: 16/500, Score: 13, Epsilon: 0.92
# Episode: 17/500, Score: 25, Epsilon: 0.92
# Episode: 18/500, Score: 14, Epsilon: 0.91
# Episode: 19/500, Score: 16, Epsilon: 0.91
# Episode: 20/500, Score: 21, Epsilon: 0.90
# Episode: 21/500, Score: 17, Epsilon: 0.90
# Episode: 22/500, Score: 23, Epsilon: 0.90
# Episode: 23/500, Score: 11, Epsilon: 0.89
# Episode: 24/500, Score: 18, Epsilon: 0.89
# Episode: 25/500, Score: 11, Epsilon: 0.88
# Episode: 26/500, Score: 14, Epsilon: 0.88
# Episode: 27/500, Score: 15, Epsilon: 0.87
# Episode: 28/500, Score: 13, Epsilon: 0.87
# Episode: 29/500, Score: 15, Epsilon: 0.86
# Episode: 30/500, Score: 23, Epsilon: 0.86
# Episode: 31/500, Score: 26, Epsilon: 0.86
# Episode: 32/500, Score: 18, Epsilon: 0.85
# Episode: 33/500, Score: 13, Epsilon: 0.85
# Episode: 34/500, Score: 24, Epsilon: 0.84
# Episode: 35/500, Score: 13, Epsilon: 0.84
# Episode: 36/500, Score: 15, Epsilon: 0.83
# Episode: 37/500, Score: 17, Epsilon: 0.83
# Episode: 38/500, Score: 10, Epsilon: 0.83
# Episode: 39/500, Score: 25, Epsilon: 0.82
# Episode: 40/500, Score: 9, Epsilon: 0.82
# Episode: 41/500, Score: 10, Epsilon: 0.81
# Episode: 42/500, Score: 12, Epsilon: 0.81
# Episode: 43/500, Score: 16, Epsilon: 0.81
# Episode: 44/500, Score: 10, Epsilon: 0.80
# Episode: 45/500, Score: 12, Epsilon: 0.80
# Episode: 46/500, Score: 14, Epsilon: 0.79
# Episode: 47/500, Score: 15, Epsilon: 0.79
# Episode: 48/500, Score: 10, Epsilon: 0.79
# Episode: 49/500, Score: 11, Epsilon: 0.78
# Episode: 50/500, Score: 19, Epsilon: 0.78
# Episode: 51/500, Score: 25, Epsilon: 0.77
# Episode: 52/500, Score: 24, Epsilon: 0.77
# Episode: 53/500, Score: 54, Epsilon: 0.77
# Episode: 54/500, Score: 11, Epsilon: 0.76
# Episode: 55/500, Score: 11, Epsilon: 0.76
# Episode: 56/500, Score: 10, Epsilon: 0.76
# Episode: 57/500, Score: 15, Epsilon: 0.75
# Episode: 58/500, Score: 10, Epsilon: 0.75
# Episode: 59/500, Score: 12, Epsilon: 0.74
# Episode: 60/500, Score: 28, Epsilon: 0.74
# Episode: 61/500, Score: 13, Epsilon: 0.74
# Episode: 62/500, Score: 24, Epsilon: 0.73
# Episode: 63/500, Score: 9, Epsilon: 0.73
# Episode: 64/500, Score: 12, Epsilon: 0.73
# Episode: 65/500, Score: 13, Epsilon: 0.72
# Episode: 66/500, Score: 15, Epsilon: 0.72
# Episode: 67/500, Score: 12, Epsilon: 0.71
# Episode: 68/500, Score: 16, Epsilon: 0.71
# Episode: 69/500, Score: 18, Epsilon: 0.71
# Episode: 70/500, Score: 21, Epsilon: 0.70
# Episode: 71/500, Score: 12, Epsilon: 0.70
# Episode: 72/500, Score: 12, Epsilon: 0.70
# Episode: 73/500, Score: 11, Epsilon: 0.69
# Episode: 74/500, Score: 22, Epsilon: 0.69
# Episode: 75/500, Score: 13, Epsilon: 0.69
# Episode: 76/500, Score: 10, Epsilon: 0.68
# Episode: 77/500, Score: 9, Epsilon: 0.68
# Episode: 78/500, Score: 11, Epsilon: 0.68
# Episode: 79/500, Score: 40, Epsilon: 0.67
# Episode: 80/500, Score: 40, Epsilon: 0.67
# Episode: 81/500, Score: 12, Epsilon: 0.67
# Episode: 82/500, Score: 14, Epsilon: 0.66
# Episode: 83/500, Score: 31, Epsilon: 0.66
# Episode: 84/500, Score: 12, Epsilon: 0.66
# Episode: 85/500, Score: 45, Epsilon: 0.65
# Episode: 86/500, Score: 11, Epsilon: 0.65
# Episode: 87/500, Score: 21, Epsilon: 0.65
# Episode: 88/500, Score: 21, Epsilon: 0.64
# Episode: 89/500, Score: 25, Epsilon: 0.64
# Episode: 90/500, Score: 17, Epsilon: 0.64
# Episode: 91/500, Score: 14, Epsilon: 0.63
# Episode: 92/500, Score: 28, Epsilon: 0.63
# Episode: 93/500, Score: 36, Epsilon: 0.63
# Episode: 94/500, Score: 13, Epsilon: 0.62
# Episode: 95/500, Score: 17, Epsilon: 0.62
# Episode: 96/500, Score: 15, Epsilon: 0.62
# Episode: 97/500, Score: 112, Epsilon: 0.61
# Episode: 98/500, Score: 19, Epsilon: 0.61
# Episode: 99/500, Score: 15, Epsilon: 0.61
# Episode: 100/500, Score: 36, Epsilon: 0.61
# Episode: 101/500, Score: 22, Epsilon: 0.60
# Episode: 102/500, Score: 15, Epsilon: 0.60
# Episode: 103/500, Score: 14, Epsilon: 0.60
# Episode: 104/500, Score: 24, Epsilon: 0.59
# Episode: 105/500, Score: 32, Epsilon: 0.59
# Episode: 106/500, Score: 15, Epsilon: 0.59
# Episode: 107/500, Score: 15, Epsilon: 0.58
# Episode: 108/500, Score: 28, Epsilon: 0.58
# Episode: 109/500, Score: 14, Epsilon: 0.58
# Episode: 110/500, Score: 13, Epsilon: 0.58
# Episode: 111/500, Score: 13, Epsilon: 0.57
# Episode: 112/500, Score: 22, Epsilon: 0.57
# Episode: 113/500, Score: 14, Epsilon: 0.57
# Episode: 114/500, Score: 10, Epsilon: 0.56
# Episode: 115/500, Score: 12, Epsilon: 0.56
# Episode: 116/500, Score: 11, Epsilon: 0.56
# Episode: 117/500, Score: 18, Epsilon: 0.56
# Episode: 118/500, Score: 21, Epsilon: 0.55
# Episode: 119/500, Score: 16, Epsilon: 0.55
# Episode: 120/500, Score: 9, Epsilon: 0.55
# Episode: 121/500, Score: 26, Epsilon: 0.55
# Episode: 122/500, Score: 17, Epsilon: 0.54
# Episode: 123/500, Score: 65, Epsilon: 0.54
# Episode: 124/500, Score: 17, Epsilon: 0.54
# Episode: 125/500, Score: 25, Epsilon: 0.53
# Episode: 126/500, Score: 35, Epsilon: 0.53
# Episode: 127/500, Score: 34, Epsilon: 0.53
# Episode: 128/500, Score: 11, Epsilon: 0.53
# Episode: 129/500, Score: 36, Epsilon: 0.52
# Episode: 130/500, Score: 18, Epsilon: 0.52
# Episode: 131/500, Score: 22, Epsilon: 0.52
# Episode: 132/500, Score: 37, Epsilon: 0.52
# Episode: 133/500, Score: 15, Epsilon: 0.51
# Episode: 134/500, Score: 24, Epsilon: 0.51
# Episode: 135/500, Score: 48, Epsilon: 0.51
# Episode: 136/500, Score: 23, Epsilon: 0.51
# Episode: 137/500, Score: 56, Epsilon: 0.50
# Episode: 138/500, Score: 69, Epsilon: 0.50
# Episode: 139/500, Score: 99, Epsilon: 0.50
# Episode: 140/500, Score: 41, Epsilon: 0.50
# Episode: 141/500, Score: 19, Epsilon: 0.49
# Episode: 142/500, Score: 12, Epsilon: 0.49
# Episode: 143/500, Score: 22, Epsilon: 0.49
# Episode: 144/500, Score: 32, Epsilon: 0.49
# Episode: 145/500, Score: 61, Epsilon: 0.48
# Episode: 146/500, Score: 42, Epsilon: 0.48
# Episode: 147/500, Score: 21, Epsilon: 0.48
# Episode: 148/500, Score: 44, Epsilon: 0.48
# Episode: 149/500, Score: 25, Epsilon: 0.47
# Episode: 150/500, Score: 46, Epsilon: 0.47
# Episode: 151/500, Score: 45, Epsilon: 0.47
# Episode: 152/500, Score: 47, Epsilon: 0.47
# Episode: 153/500, Score: 67, Epsilon: 0.46
# Episode: 154/500, Score: 11, Epsilon: 0.46
# Episode: 155/500, Score: 14, Epsilon: 0.46
# Episode: 156/500, Score: 32, Epsilon: 0.46
# Episode: 157/500, Score: 20, Epsilon: 0.46
# Episode: 158/500, Score: 16, Epsilon: 0.45
# Episode: 159/500, Score: 42, Epsilon: 0.45
# Episode: 160/500, Score: 35, Epsilon: 0.45
# Episode: 161/500, Score: 37, Epsilon: 0.45
# Episode: 162/500, Score: 15, Epsilon: 0.44
# Episode: 163/500, Score: 32, Epsilon: 0.44
# Episode: 164/500, Score: 82, Epsilon: 0.44
# Episode: 165/500, Score: 94, Epsilon: 0.44
# Episode: 166/500, Score: 42, Epsilon: 0.44
# Episode: 167/500, Score: 15, Epsilon: 0.43
# Episode: 168/500, Score: 32, Epsilon: 0.43
# Episode: 169/500, Score: 36, Epsilon: 0.43
# Episode: 170/500, Score: 34, Epsilon: 0.43
# Episode: 171/500, Score: 22, Epsilon: 0.42
# Episode: 172/500, Score: 19, Epsilon: 0.42
# Episode: 173/500, Score: 15, Epsilon: 0.42
# Episode: 174/500, Score: 30, Epsilon: 0.42
# Episode: 175/500, Score: 15, Epsilon: 0.42
# Episode: 176/500, Score: 88, Epsilon: 0.41
# Episode: 177/500, Score: 35, Epsilon: 0.41
# Episode: 178/500, Score: 23, Epsilon: 0.41
# Episode: 179/500, Score: 20, Epsilon: 0.41
# Episode: 180/500, Score: 48, Epsilon: 0.41
# Episode: 181/500, Score: 21, Epsilon: 0.40
# Episode: 182/500, Score: 21, Epsilon: 0.40
# Episode: 183/500, Score: 18, Epsilon: 0.40
# Episode: 184/500, Score: 22, Epsilon: 0.40
# Episode: 185/500, Score: 72, Epsilon: 0.40
# Episode: 186/500, Score: 15, Epsilon: 0.39
# Episode: 187/500, Score: 36, Epsilon: 0.39
# Episode: 188/500, Score: 25, Epsilon: 0.39
# Episode: 189/500, Score: 17, Epsilon: 0.39
# Episode: 190/500, Score: 14, Epsilon: 0.39
# Episode: 191/500, Score: 13, Epsilon: 0.38
# Episode: 192/500, Score: 24, Epsilon: 0.38
# Episode: 193/500, Score: 17, Epsilon: 0.38
# Episode: 194/500, Score: 28, Epsilon: 0.38
# Episode: 195/500, Score: 19, Epsilon: 0.38
# Episode: 196/500, Score: 16, Epsilon: 0.37
# Episode: 197/500, Score: 20, Epsilon: 0.37
# Episode: 198/500, Score: 13, Epsilon: 0.37
# Episode: 199/500, Score: 34, Epsilon: 0.37
# Episode: 200/500, Score: 32, Epsilon: 0.37
# Episode: 201/500, Score: 22, Epsilon: 0.37
# Episode: 202/500, Score: 33, Epsilon: 0.36
# Episode: 203/500, Score: 33, Epsilon: 0.36
# Episode: 204/500, Score: 62, Epsilon: 0.36
# Episode: 205/500, Score: 67, Epsilon: 0.36
# Episode: 206/500, Score: 14, Epsilon: 0.36
# Episode: 207/500, Score: 44, Epsilon: 0.35
# Episode: 208/500, Score: 25, Epsilon: 0.35
# Episode: 209/500, Score: 38, Epsilon: 0.35
# Episode: 210/500, Score: 17, Epsilon: 0.35
# Episode: 211/500, Score: 22, Epsilon: 0.35
# Episode: 212/500, Score: 15, Epsilon: 0.35
# Episode: 213/500, Score: 39, Epsilon: 0.34
# Episode: 214/500, Score: 25, Epsilon: 0.34
# Episode: 215/500, Score: 35, Epsilon: 0.34
# Episode: 216/500, Score: 27, Epsilon: 0.34
# Episode: 217/500, Score: 28, Epsilon: 0.34
# Episode: 218/500, Score: 47, Epsilon: 0.34
# Episode: 219/500, Score: 64, Epsilon: 0.33
# Episode: 220/500, Score: 38, Epsilon: 0.33
# Episode: 221/500, Score: 46, Epsilon: 0.33
# Episode: 222/500, Score: 31, Epsilon: 0.33
# Episode: 223/500, Score: 34, Epsilon: 0.33
# Episode: 224/500, Score: 28, Epsilon: 0.33
# Episode: 225/500, Score: 25, Epsilon: 0.32
# Episode: 226/500, Score: 16, Epsilon: 0.32
# Episode: 227/500, Score: 17, Epsilon: 0.32
# Episode: 228/500, Score: 59, Epsilon: 0.32
# Episode: 229/500, Score: 34, Epsilon: 0.32
# Episode: 230/500, Score: 58, Epsilon: 0.32
# Episode: 231/500, Score: 24, Epsilon: 0.31
# Episode: 232/500, Score: 48, Epsilon: 0.31
# Episode: 233/500, Score: 13, Epsilon: 0.31
# Episode: 234/500, Score: 28, Epsilon: 0.31
# Episode: 235/500, Score: 29, Epsilon: 0.31
# Episode: 236/500, Score: 31, Epsilon: 0.31
# Episode: 237/500, Score: 46, Epsilon: 0.30
# Episode: 238/500, Score: 25, Epsilon: 0.30
# Episode: 239/500, Score: 46, Epsilon: 0.30
# Episode: 240/500, Score: 65, Epsilon: 0.30
# Episode: 241/500, Score: 57, Epsilon: 0.30
# Episode: 242/500, Score: 32, Epsilon: 0.30
# Episode: 243/500, Score: 46, Epsilon: 0.30
# Episode: 244/500, Score: 42, Epsilon: 0.29
# Episode: 245/500, Score: 34, Epsilon: 0.29
# Episode: 246/500, Score: 27, Epsilon: 0.29
# Episode: 247/500, Score: 57, Epsilon: 0.29
# Episode: 248/500, Score: 35, Epsilon: 0.29
# Episode: 249/500, Score: 26, Epsilon: 0.29
# Episode: 250/500, Score: 71, Epsilon: 0.29
# Episode: 251/500, Score: 29, Epsilon: 0.28
# Episode: 252/500, Score: 37, Epsilon: 0.28
# Episode: 253/500, Score: 25, Epsilon: 0.28
# Episode: 254/500, Score: 39, Epsilon: 0.28
# Episode: 255/500, Score: 122, Epsilon: 0.28
# Episode: 256/500, Score: 31, Epsilon: 0.28
# Episode: 257/500, Score: 37, Epsilon: 0.28
# Episode: 258/500, Score: 102, Epsilon: 0.27
# Episode: 259/500, Score: 22, Epsilon: 0.27
# Episode: 260/500, Score: 39, Epsilon: 0.27
# Episode: 261/500, Score: 46, Epsilon: 0.27
# Episode: 262/500, Score: 44, Epsilon: 0.27
# Episode: 263/500, Score: 22, Epsilon: 0.27
# Episode: 264/500, Score: 23, Epsilon: 0.27
# Episode: 265/500, Score: 30, Epsilon: 0.26
# Episode: 266/500, Score: 30, Epsilon: 0.26
# Episode: 267/500, Score: 28, Epsilon: 0.26
# Episode: 268/500, Score: 34, Epsilon: 0.26
# Episode: 269/500, Score: 60, Epsilon: 0.26
# Episode: 270/500, Score: 43, Epsilon: 0.26
# Episode: 271/500, Score: 37, Epsilon: 0.26
# Episode: 272/500, Score: 55, Epsilon: 0.26
# Episode: 273/500, Score: 59, Epsilon: 0.25
# Episode: 274/500, Score: 49, Epsilon: 0.25
# Episode: 275/500, Score: 80, Epsilon: 0.25
# Episode: 276/500, Score: 72, Epsilon: 0.25
# Episode: 277/500, Score: 53, Epsilon: 0.25
# Episode: 278/500, Score: 32, Epsilon: 0.25
# Episode: 279/500, Score: 24, Epsilon: 0.25
# Episode: 280/500, Score: 56, Epsilon: 0.25
# Episode: 281/500, Score: 62, Epsilon: 0.24
# Episode: 282/500, Score: 35, Epsilon: 0.24
# Episode: 283/500, Score: 45, Epsilon: 0.24
# Episode: 284/500, Score: 54, Epsilon: 0.24
# Episode: 285/500, Score: 52, Epsilon: 0.24
# Episode: 286/500, Score: 83, Epsilon: 0.24
# Episode: 287/500, Score: 45, Epsilon: 0.24
# Episode: 288/500, Score: 23, Epsilon: 0.24
# Episode: 289/500, Score: 24, Epsilon: 0.23
# Episode: 290/500, Score: 30, Epsilon: 0.23
# Episode: 291/500, Score: 24, Epsilon: 0.23
# Episode: 292/500, Score: 24, Epsilon: 0.23
# Episode: 293/500, Score: 24, Epsilon: 0.23
# Episode: 294/500, Score: 25, Epsilon: 0.23
# Episode: 295/500, Score: 26, Epsilon: 0.23
# Episode: 296/500, Score: 64, Epsilon: 0.23
# Episode: 297/500, Score: 49, Epsilon: 0.23
# Episode: 298/500, Score: 30, Epsilon: 0.22
# Episode: 299/500, Score: 24, Epsilon: 0.22
# Episode: 300/500, Score: 13, Epsilon: 0.22
# Episode: 301/500, Score: 24, Epsilon: 0.22
# Episode: 302/500, Score: 16, Epsilon: 0.22
# Episode: 303/500, Score: 34, Epsilon: 0.22
# Episode: 304/500, Score: 16, Epsilon: 0.22
# Episode: 305/500, Score: 28, Epsilon: 0.22
# Episode: 306/500, Score: 24, Epsilon: 0.22
# Episode: 307/500, Score: 103, Epsilon: 0.21
# Episode: 308/500, Score: 142, Epsilon: 0.21
# Episode: 309/500, Score: 112, Epsilon: 0.21
# Episode: 310/500, Score: 127, Epsilon: 0.21
# Episode: 311/500, Score: 124, Epsilon: 0.21
# Episode: 312/500, Score: 102, Epsilon: 0.21
# Episode: 313/500, Score: 198, Epsilon: 0.21
# Episode: 314/500, Score: 157, Epsilon: 0.21
# Episode: 315/500, Score: 124, Epsilon: 0.21
# Episode: 316/500, Score: 132, Epsilon: 0.21
# Episode: 317/500, Score: 149, Epsilon: 0.20
# Episode: 318/500, Score: 23, Epsilon: 0.20
# Episode: 319/500, Score: 29, Epsilon: 0.20
# Episode: 320/500, Score: 31, Epsilon: 0.20
# Episode: 321/500, Score: 21, Epsilon: 0.20
# Episode: 322/500, Score: 23, Epsilon: 0.20
# Episode: 323/500, Score: 241, Epsilon: 0.20
# Episode: 324/500, Score: 158, Epsilon: 0.20
# Episode: 325/500, Score: 124, Epsilon: 0.20
# Episode: 326/500, Score: 27, Epsilon: 0.20
# Episode: 327/500, Score: 112, Epsilon: 0.19
# Episode: 328/500, Score: 136, Epsilon: 0.19
# Episode: 329/500, Score: 245, Epsilon: 0.19
# Episode: 330/500, Score: 182, Epsilon: 0.19
# Episode: 331/500, Score: 272, Epsilon: 0.19
# Episode: 332/500, Score: 105, Epsilon: 0.19
# Episode: 333/500, Score: 133, Epsilon: 0.19
# Episode: 334/500, Score: 147, Epsilon: 0.19
# Episode: 335/500, Score: 133, Epsilon: 0.19
# Episode: 336/500, Score: 169, Epsilon: 0.19
# Episode: 337/500, Score: 200, Epsilon: 0.18
# Episode: 338/500, Score: 161, Epsilon: 0.18
# Episode: 339/500, Score: 160, Epsilon: 0.18
# Episode: 340/500, Score: 92, Epsilon: 0.18
# Episode: 341/500, Score: 165, Epsilon: 0.18
# Episode: 342/500, Score: 132, Epsilon: 0.18
# Episode: 343/500, Score: 111, Epsilon: 0.18
# Episode: 344/500, Score: 104, Epsilon: 0.18
# Episode: 345/500, Score: 117, Epsilon: 0.18
# Episode: 346/500, Score: 108, Epsilon: 0.18
# Episode: 347/500, Score: 120, Epsilon: 0.18
# Episode: 348/500, Score: 122, Epsilon: 0.17
# Episode: 349/500, Score: 129, Epsilon: 0.17
# Episode: 350/500, Score: 127, Epsilon: 0.17
# Episode: 351/500, Score: 110, Epsilon: 0.17
# Episode: 352/500, Score: 118, Epsilon: 0.17
# Episode: 353/500, Score: 113, Epsilon: 0.17
# Episode: 354/500, Score: 126, Epsilon: 0.17
# Episode: 355/500, Score: 125, Epsilon: 0.17
# Episode: 356/500, Score: 139, Epsilon: 0.17
# Episode: 357/500, Score: 141, Epsilon: 0.17
# Episode: 358/500, Score: 156, Epsilon: 0.17
# Episode: 359/500, Score: 143, Epsilon: 0.17
# Episode: 360/500, Score: 128, Epsilon: 0.16
# Episode: 361/500, Score: 129, Epsilon: 0.16
# Episode: 362/500, Score: 140, Epsilon: 0.16
# Episode: 363/500, Score: 120, Epsilon: 0.16
# Episode: 364/500, Score: 146, Epsilon: 0.16
# Episode: 365/500, Score: 132, Epsilon: 0.16
# Episode: 366/500, Score: 275, Epsilon: 0.16
# Episode: 367/500, Score: 47, Epsilon: 0.16
# Episode: 368/500, Score: 41, Epsilon: 0.16
# Episode: 369/500, Score: 309, Epsilon: 0.16
# Episode: 370/500, Score: 220, Epsilon: 0.16
# Episode: 371/500, Score: 221, Epsilon: 0.16
# Episode: 372/500, Score: 229, Epsilon: 0.15
# Episode: 373/500, Score: 214, Epsilon: 0.15
# Episode: 374/500, Score: 258, Epsilon: 0.15
# Episode: 375/500, Score: 148, Epsilon: 0.15
# Episode: 376/500, Score: 95, Epsilon: 0.15
# Episode: 377/500, Score: 98, Epsilon: 0.15
# Episode: 378/500, Score: 120, Epsilon: 0.15
# Episode: 379/500, Score: 153, Epsilon: 0.15
# Episode: 380/500, Score: 71, Epsilon: 0.15
# Episode: 381/500, Score: 84, Epsilon: 0.15
# Episode: 382/500, Score: 76, Epsilon: 0.15
# Episode: 383/500, Score: 59, Epsilon: 0.15
# Episode: 384/500, Score: 33, Epsilon: 0.15
# Episode: 385/500, Score: 28, Epsilon: 0.15
# Episode: 386/500, Score: 45, Epsilon: 0.14
# Episode: 387/500, Score: 74, Epsilon: 0.14
# Episode: 388/500, Score: 156, Epsilon: 0.14
# Episode: 389/500, Score: 208, Epsilon: 0.14
# Episode: 390/500, Score: 80, Epsilon: 0.14
# Episode: 391/500, Score: 93, Epsilon: 0.14
# Episode: 392/500, Score: 116, Epsilon: 0.14
# Episode: 393/500, Score: 215, Epsilon: 0.14
# Episode: 394/500, Score: 188, Epsilon: 0.14
# Episode: 395/500, Score: 36, Epsilon: 0.14
# Episode: 396/500, Score: 28, Epsilon: 0.14
# Episode: 397/500, Score: 107, Epsilon: 0.14
# Episode: 398/500, Score: 121, Epsilon: 0.14
# Episode: 399/500, Score: 105, Epsilon: 0.14
# Episode: 400/500, Score: 103, Epsilon: 0.13
# Episode: 401/500, Score: 97, Epsilon: 0.13
# Episode: 402/500, Score: 117, Epsilon: 0.13
# Episode: 403/500, Score: 122, Epsilon: 0.13
# Episode: 404/500, Score: 250, Epsilon: 0.13
# Episode: 405/500, Score: 169, Epsilon: 0.13
# Episode: 406/500, Score: 158, Epsilon: 0.13
# Episode: 407/500, Score: 154, Epsilon: 0.13
# Episode: 408/500, Score: 119, Epsilon: 0.13
# Episode: 409/500, Score: 145, Epsilon: 0.13
# Episode: 410/500, Score: 237, Epsilon: 0.13
# Episode: 411/500, Score: 180, Epsilon: 0.13
# Episode: 412/500, Score: 400, Epsilon: 0.13
# Episode: 413/500, Score: 153, Epsilon: 0.13
# Episode: 414/500, Score: 118, Epsilon: 0.13
# Episode: 415/500, Score: 185, Epsilon: 0.12
# Episode: 416/500, Score: 172, Epsilon: 0.12
# Episode: 417/500, Score: 179, Epsilon: 0.12
# Episode: 418/500, Score: 155, Epsilon: 0.12
# Episode: 419/500, Score: 189, Epsilon: 0.12
# Episode: 420/500, Score: 398, Epsilon: 0.12
# Episode: 421/500, Score: 174, Epsilon: 0.12
# Episode: 422/500, Score: 216, Epsilon: 0.12
# Episode: 423/500, Score: 291, Epsilon: 0.12
# Episode: 424/500, Score: 378, Epsilon: 0.12
# Episode: 425/500, Score: 203, Epsilon: 0.12
# Episode: 426/500, Score: 168, Epsilon: 0.12
# Episode: 427/500, Score: 210, Epsilon: 0.12
# Episode: 428/500, Score: 261, Epsilon: 0.12
# Episode: 429/500, Score: 189, Epsilon: 0.12
# Episode: 430/500, Score: 144, Epsilon: 0.12
# Episode: 431/500, Score: 110, Epsilon: 0.12
# Episode: 432/500, Score: 499, Epsilon: 0.11
# Episode: 433/500, Score: 154, Epsilon: 0.11
# Episode: 434/500, Score: 85, Epsilon: 0.11
# Episode: 435/500, Score: 117, Epsilon: 0.11
# Episode: 436/500, Score: 116, Epsilon: 0.11
# Episode: 437/500, Score: 231, Epsilon: 0.11
# Episode: 438/500, Score: 113, Epsilon: 0.11
# Episode: 439/500, Score: 113, Epsilon: 0.11
# Episode: 440/500, Score: 112, Epsilon: 0.11
# Episode: 441/500, Score: 35, Epsilon: 0.11
# Episode: 442/500, Score: 109, Epsilon: 0.11
# Episode: 443/500, Score: 312, Epsilon: 0.11
# Episode: 444/500, Score: 234, Epsilon: 0.11
# Episode: 445/500, Score: 169, Epsilon: 0.11
# Episode: 446/500, Score: 154, Epsilon: 0.11
# Episode: 447/500, Score: 150, Epsilon: 0.11
# Episode: 448/500, Score: 94, Epsilon: 0.11
# Episode: 449/500, Score: 114, Epsilon: 0.11
# Episode: 450/500, Score: 236, Epsilon: 0.10
# Episode: 451/500, Score: 245, Epsilon: 0.10
# Episode: 452/500, Score: 291, Epsilon: 0.10
# Episode: 453/500, Score: 170, Epsilon: 0.10
# Episode: 454/500, Score: 196, Epsilon: 0.10
# Episode: 455/500, Score: 298, Epsilon: 0.10
# Episode: 456/500, Score: 275, Epsilon: 0.10
# Episode: 457/500, Score: 323, Epsilon: 0.10
# Episode: 458/500, Score: 195, Epsilon: 0.10
# Episode: 459/500, Score: 177, Epsilon: 0.10
# Episode: 460/500, Score: 179, Epsilon: 0.10
# Episode: 461/500, Score: 147, Epsilon: 0.10
# Episode: 462/500, Score: 171, Epsilon: 0.10
# Episode: 463/500, Score: 499, Epsilon: 0.10
# Episode: 464/500, Score: 143, Epsilon: 0.10
# Episode: 465/500, Score: 158, Epsilon: 0.10
# Episode: 466/500, Score: 120, Epsilon: 0.10
# Episode: 467/500, Score: 111, Epsilon: 0.10
# Episode: 468/500, Score: 175, Epsilon: 0.10
# Episode: 469/500, Score: 158, Epsilon: 0.10
# Episode: 470/500, Score: 101, Epsilon: 0.09
# Episode: 471/500, Score: 140, Epsilon: 0.09
# Episode: 472/500, Score: 80, Epsilon: 0.09
# Episode: 473/500, Score: 129, Epsilon: 0.09
# Episode: 474/500, Score: 236, Epsilon: 0.09
# Episode: 475/500, Score: 162, Epsilon: 0.09
# Episode: 476/500, Score: 214, Epsilon: 0.09
# Episode: 477/500, Score: 144, Epsilon: 0.09
# Episode: 478/500, Score: 137, Epsilon: 0.09
# Episode: 479/500, Score: 140, Epsilon: 0.09
# Episode: 480/500, Score: 85, Epsilon: 0.09
# Episode: 481/500, Score: 158, Epsilon: 0.09
# Episode: 482/500, Score: 135, Epsilon: 0.09
# Episode: 483/500, Score: 98, Epsilon: 0.09
# Episode: 484/500, Score: 121, Epsilon: 0.09
# Episode: 485/500, Score: 165, Epsilon: 0.09
# Episode: 486/500, Score: 280, Epsilon: 0.09
# Episode: 487/500, Score: 96, Epsilon: 0.09
# Episode: 488/500, Score: 99, Epsilon: 0.09
# Episode: 489/500, Score: 100, Epsilon: 0.09
# Episode: 490/500, Score: 83, Epsilon: 0.09
# Episode: 491/500, Score: 85, Epsilon: 0.09
# Episode: 492/500, Score: 73, Epsilon: 0.08
# Episode: 493/500, Score: 102, Epsilon: 0.08
# Episode: 494/500, Score: 100, Epsilon: 0.08
# Episode: 495/500, Score: 87, Epsilon: 0.08
# Episode: 496/500, Score: 106, Epsilon: 0.08
# Episode: 497/500, Score: 87, Epsilon: 0.08
# Episode: 498/500, Score: 62, Epsilon: 0.08
# Episode: 499/500, Score: 116, Epsilon: 0.08

# %%
def render_episode(agent, model_path, num_episodes=1):
    # Load the model
    agent.load_model(model_path)
    
    env = gym.make('CartPole-v1', render_mode='human')
    for episode in range(num_episodes):
        state, _ = env.reset()
        state = state.reshape(1, -1)
        done = False
        total_reward = 0
        while not done:
            env.render()
            action = agent.act(state)
            next_state, reward, done, truncated, _ = env.step(action)
            next_state = next_state.reshape(1, -1)
            total_reward += reward
            state = next_state
            if truncated:
                done = True
        print(f"Episode {episode + 1} reward: {total_reward}")
    env.close()

# Initializing saved model
state_size = 4
action_size = 2
agent = Agent(state_size, action_size)
agent.epsilon = 0.0  # 0.0 for pure exploitation

# Load the model and render episodes
model_path = "./cartpole_model/model_100.keras"
# model_path = "./cartpole_model/DQN_old.keras"
render_episode(agent, model_path, num_episodes=2)
# Out:
# Episode 1 reward: 27.0
# Episode 2 reward: 38.0
